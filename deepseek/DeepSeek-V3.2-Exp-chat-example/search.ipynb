# %%
# 安装必要的包
# !pip install huggingface_hub -q

# %%
import pandas as pd

# Login using e.g. `huggingface-cli login` to access this dataset
df = pd.read_json("hf://datasets/Jackrong/Chinese-DeepSeek-V3.2-Exp-chat-example/deepseek_v32_Exp_chat.jsonl", lines=True)

# %%
df.head()
# Out:
#                 generator                                       conversation  \
# 0  DeepSeek-V3.2-Exp-chat  [{'role': 'user', 'content': '食堂运来400千克面粉，第一周吃...
# 1  DeepSeek-V3.2-Exp-chat  [{'role': 'user', 'content': '若向量 $\boldsymbol...
# 2  DeepSeek-V3.2-Exp-chat  [{'role': 'user', 'content': '已知函数 $\mathrm{f}...
# 3  DeepSeek-V3.2-Exp-chat  [{'role': 'user', 'content': '4（1）班有46人，其中会弹钢琴...
# 4  DeepSeek-V3.2-Exp-chat  [{'role': 'user', 'content': '96人排成3个方队做操，每个方队...
#
#                                              problem  \
# 0  食堂运来400千克面粉，第一周吃了总数的(3/10)，第二周吃了总数的(3/8)，还剩下多少...
# 1  若向量 $\boldsymbol{a}, \boldsymbol{b}$ 满足 $|\bol...
# 2  已知函数 $\mathrm{f}(x)$ 的导函数为 $\mathrm{f}^{\prime...
# 3  4（1）班有46人，其中会弹钢琴的有30人，会拉小提琴的有28人，则这个班既会弹钢琴又会拉小...
# 4                     96人排成3个方队做操，每个方队站成4列，平均每列站多少人？
#
#                                               answer  len_problem  len_answer  \
# 0  好，我们一步步来解这道题。  \n\n---\n\n**1. 理解题意**  \n面粉总量：...           51         471
# ...
